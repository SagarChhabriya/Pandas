# %% [markdown]
# # D-Tale
#
# ![image.png](attachment:image.png)
#
#
#
# Allows you to run many common Pandas operations with no code.
#
# Exports code of analysis.
#
# Integrates with Jupyter Notebook.
#
# Covers info about missing values, data statistics, correlation, etc.
#
# Highlights duplicates, outliers, etc.
#
# Get started: [GitHub](https://substack.com/redirect/39136992-ab06-4942-802b-653150fdb29c?j=eyJ1IjoiM3ExaWtvIn0.yEdRunDTPnl4eZ269_JlcuL8w2XriGxrW87RvsAWn8g)

# %% [markdown]
# - conda
# conda install dtale -c conda-forge
#
# - if you want to also use "Export to PNG" for charts
# conda install -c plotly python-kaleido
#
# - or PyPI
# pip install dtale

# %%
import pandas as pd
import seaborn as sns
import dtale

# %%
df = sns.load_dataset("titanic")
dtale.show(df)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://RADHERADHE:40000/dtale/iframe/1"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
