# %% [markdown]
# # AutoViz
# Supports CSV, TXT, and JSON.
#
# Interactive Bokeh charts.
#
# Covers info about missing values, data statistics, correlation, etc.
#
# Presents data cleaning suggestions.
#
# Get started: [GitHub](https://substack.com/redirect/6d9776ac-5dc8-4185-aed3-2a1774c77e2b?j=eyJ1IjoiM3ExaWtvIn0.yEdRunDTPnl4eZ269_JlcuL8w2XriGxrW87RvsAWn8g)

# %% [markdown]
# ![image.png](attachment:image.png)
