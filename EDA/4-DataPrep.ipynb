# %% [markdown]
# # DataPrep
# Produces interactive visualizations.
#
# Typically faster than other common tools.
#
# Supports Pandas and Dask DataFrames.
#
# Covers info about missing values, data statistics, correlation, etc.
#
# Plots data feature interactions.
#
# Get started: [GitHub](https://substack.com/redirect/d97b032d-3b33-4011-bef1-b97a811b717d?j=eyJ1IjoiM3ExaWtvIn0.yEdRunDTPnl4eZ269_JlcuL8w2XriGxrW87RvsAWn8g)
#
# pip install -U dataprep

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#  it couldn't be downloaded on my local machine because
#  "error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for regex
# Failed to build levenshtein pandas regex
# ERROR: ERROR: Failed to build installable wheels for some pyproject.toml based projects (levenshtein, pandas, regex)"
#
#  No library is better than this ![image.png](attachment:image.png)

# %%
# from dataprep.datasets import load_dataset
# from dataprep.eda import create_report
# df = load_dataset("titanic")
# create_report(df).show_browser()
