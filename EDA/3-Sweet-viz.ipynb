# %% [markdown]
# # Sweet-viz
#
# - Creates a variety of data visualizations.
#
# - Covers information about missing values, data statistics, etc.
#
# - Integrates with Jupyter Notebook.
#
# - pip install -U dataprep
#
# [Documentation on GitHub](https://substack.com/redirect/9f39719a-583b-4297-a4ed-d5ae5bb70cdd?j=eyJ1IjoiM3ExaWtvIn0.yEdRunDTPnl4eZ269_JlcuL8w2XriGxrW87RvsAWn8g)

# %% [markdown]
# ![WhatsApp Image 2024-07-06 at 15.31.43_d3f79c8f.jpg](<attachment:WhatsApp Image 2024-07-06 at 15.31.43_d3f79c8f.jpg>)

# %%
import sweetviz as sv
import seaborn as sns

# %%
df = sns.load_dataset('titanic')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
report = sv.analyze(df)
report.show_html("3-sv-titanic.html")
# Out:
# Done! Use 'show' commands to display/save.   |██████████| [100%]   00:00 -> (00:00 left)
# Report sv-titanic.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
report.show_notebook()
# Out:
#  <iframe width="100%" height="750" srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;UTF-8&quot;&gt;
#     &lt;link rel=&quot;icon&quot; href=&quot;data:image/x-icon;base64,...&quot; type=&quot;image/x-icon&quot; /&gt;
#         &lt;script&gt; /*! jQuery v3.7.1 | (c) OpenJS Foundation and other contributors | jquery.org/license */
# ...
