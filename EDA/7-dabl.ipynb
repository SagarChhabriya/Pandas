# %% [markdown]
# # dabl
#     Data Analysis Base Line Library
#
# ![image.png](attachment:image.png)
#
# - Primarily provides visualizations.
#
# - Covers a wide range of plots:
#
#     - Target distribution.
#
#     - Scatter pair plots.
#
#     - Histograms.
#
# Get started: [GitHub](https://substack.com/redirect/e95a0fdc-2323-4ee5-9a06-16c5f3d5718c?j=eyJ1IjoiM3ExaWtvIn0.yEdRunDTPnl4eZ269_JlcuL8w2XriGxrW87RvsAWn8g)
#
#
# `pip install dabl`

# %%
import pandas as pd
import seaborn as sns
# Load the Titanic dataset from Dabl
titanic_data = sns.load_dataset("titanic")

# Display the first few rows of the dataset
print(titanic_data.head())
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
import dabl
import seaborn as sns
import matplotlib.pyplot as plt

# Load the Titanic dataset from Seaborn
titanic_data = sns.load_dataset("titanic")

# Plotting and exploring the dataset
dabl.plot(titanic_data, target_col='survived')

# Manually handle legend creation
handles, labels = plt.gca().get_legend_handles_labels()
plt.legend(handles=handles, labels=labels)

plt.show()
# Out:
# d:\Ao\Code\PyCode\pandas\EDA\.venv\Lib\site-packages\dabl\preprocessing.py:172: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(series[:10])
# d:\Ao\Code\PyCode\pandas\EDA\.venv\Lib\site-packages\dabl\preprocessing.py:172: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(series[:10])
# d:\Ao\Code\PyCode\pandas\EDA\.venv\Lib\site-packages\dabl\preprocessing.py:172: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(series[:10])
# ...

# %%
import dabl
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_digits
X, y = load_digits(return_X_y=True)
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)
sc = dabl.SimpleClassifier().fit(X_train, y_train)
# Out:
# Running DummyClassifier()
# 0: nan
# d:\Ao\Code\PyCode\pandas\EDA\.venv\Lib\site-packages\sklearn\model_selection\_validation.py:982: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "d:\Ao\Code\PyCode\pandas\EDA\.venv\Lib\site-packages\sklearn\model_selection\_validation.py", line 971, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: 'dict' object is not callable
#
#   warnings.warn(
# d:\Ao\Code\PyCode\pandas\EDA\.venv\Lib\site-packages\sklearn\model_selection\_validation.py:982: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "d:\Ao\Code\PyCode\pandas\EDA\.venv\Lib\site-packages\sklearn\model_selection\_validation.py", line 971, in _score
# ...
